# %%
"""
data simulation and fitting for 3-arm bandit task (combined model with lapse as used in fapia)
"""
import os, sys
import numpy as np
import pandas as pd
import stan
from scipy.special import softmax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import numpy as np
#       6 import pandas as pd
# ----> 7 import stan
#       8 from scipy.special import softmax
#
# ModuleNotFoundError: No module named 'stan'

# %%
pip install pystan
# Out:
# Collecting pystan
#   Using cached pystan-3.6.0-py3-none-any.whl (13 kB)
# Collecting aiohttp<4.0,>=3.6
#   Using cached aiohttp-3.8.4-cp311-cp311-win_amd64.whl (317 kB)
# Collecting clikit<0.7,>=0.6
#   Using cached clikit-0.6.2-py2.py3-none-any.whl (91 kB)
# Collecting pystan
#   Using cached pystan-3.5.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.4.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.3.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.2.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.1.1-py3-none-any.whl (13 kB)
#   Using cached pystan-3.1.0-py3-none-any.whl (13 kB)
#   Using cached pystan-3.0.2-py3-none-any.whl (13 kB)
#   Using cached pystan-3.0.1-py3-none-any.whl (12 kB)
#   Using cached pystan-3.0.0-py3-none-any.whl (12 kB)
#   Using cached pystan-2.19.1.1.tar.gz (16.2 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in c:\users\swati rajwal\appdata\local\programs\python\python311\lib\site-packages (from pystan) (0.29.33)
# Requirement already satisfied: numpy>=1.7 in c:\users\swati rajwal\appdata\local\programs\python\python311\lib\site-packages (from pystan) (1.24.2)
# Installing collected packages: pystan
#   Running setup.py install for pystan: started
#   Running setup.py install for pystan: still running...
#   Running setup.py install for pystan: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: pystan is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for pystan did not run successfully.
#   │ exit code: 1
#   ╰─> [11736 lines of output]
#       C:\Users\Swati Rajwal\AppData\Local\Temp\pip-install-g4i_osma\pystan_ffcb646ae2ac426196013c6232dbb69f\setup.py:235: DeprecationWarning:
#
#         `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#         of the deprecation of `distutils` itself. It will be removed for
#         Python >= 3.12. For older Python versions it will remain present.
#         It is recommended to use `setuptools < 60.0` for those Python versions.
#         For more details, see:
#           https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#         from numpy.distutils.command import install
#       Compiling pystan/_api.pyx because it depends on c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\Cython\Includes\libcpp\vector.pxd.
#       Compiling pystan/_chains.pyx because it depends on c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\Cython\Includes\libcpp\vector.pxd.
#       [1/2] Cythonizing pystan/_api.pyx
#       [2/2] Cythonizing pystan/_chains.pyx
#       running install
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#         warnings.warn(
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\pystan
#       copying pystan\api.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\chains.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\constants.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\diagnostics.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\lookup.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\misc.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\model.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\plots.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\_compat.py -> build\lib.win-amd64-cpython-311\pystan
#       copying pystan\__init__.py -> build\lib.win-amd64-cpython-311\pystan
#       creating build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\helper.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_basic.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_basic_array.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_basic_matrix.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_basic_pars.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_chains.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_covexpquad.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_ess.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_euclidian_metric.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_external_cpp.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_extract.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_extra_compile_args.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_fixed_param.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_generated_quantities_seed.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_linear_regression.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_lookup.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_misc.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_misc_args.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_optimizing_example.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_pickle.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_posterior_means.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_rstan_getting_started.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_rstan_stanfit.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_rstan_stan_args.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_rstan_testoptim.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_stanc.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_stan_file_io.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_unconstrain_pars.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_user_inits.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_utf8.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\test_vb.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       copying pystan\tests\__init__.py -> build\lib.win-amd64-cpython-311\pystan\tests
#       creating build\lib.win-amd64-cpython-311\pystan\experimental
#       copying pystan\experimental\misc.py -> build\lib.win-amd64-cpython-311\pystan\experimental
#       copying pystan\experimental\pickling_tools.py -> build\lib.win-amd64-cpython-311\pystan\experimental
#       copying pystan\experimental\__init__.py -> build\lib.win-amd64-cpython-311\pystan\experimental
#       creating build\lib.win-amd64-cpython-311\pystan\external
#       copying pystan\external\__init__.py -> build\lib.win-amd64-cpython-311\pystan\external
#       creating build\lib.win-amd64-cpython-311\pystan\external\pymc
#       copying pystan\external\pymc\plots.py -> build\lib.win-amd64-cpython-311\pystan\external\pymc
#       copying pystan\external\pymc\stats.py -> build\lib.win-amd64-cpython-311\pystan\external\pymc
#       copying pystan\external\pymc\trace.py -> build\lib.win-amd64-cpython-311\pystan\external\pymc
#       copying pystan\external\pymc\__init__.py -> build\lib.win-amd64-cpython-311\pystan\external\pymc
#       creating build\lib.win-amd64-cpython-311\pystan\external\enum
#       copying pystan\external\enum\enum.py -> build\lib.win-amd64-cpython-311\pystan\external\enum
#       copying pystan\external\enum\__init__.py -> build\lib.win-amd64-cpython-311\pystan\external\enum
#       creating build\lib.win-amd64-cpython-311\pystan\external\scipy
#       copying pystan\external\scipy\mstats.py -> build\lib.win-amd64-cpython-311\pystan\external\scipy
#       copying pystan\external\scipy\__init__.py -> build\lib.win-amd64-cpython-311\pystan\external\scipy
#       running egg_info
#       creating pystan.egg-info
#       writing pystan.egg-info\PKG-INFO
#       writing dependency_links to pystan.egg-info\dependency_links.txt
#       writing requirements to pystan.egg-info\requires.txt
#       writing top-level names to pystan.egg-info\top_level.txt
#       writing manifest file 'pystan.egg-info\SOURCES.txt'
#       reading manifest file 'pystan.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       no previously-included directories found matching 'doc\_build'
#       warning: no previously-included files matching '*.so' found anywhere in distribution
#       warning: no previously-included files matching '*.pyc' found anywhere in distribution
#       warning: no previously-included files matching '.git*' found anywhere in distribution
#       warning: no previously-included files matching '*.png' found anywhere in distribution
#       no previously-included directories found matching 'pystan\stan\make'
#       no previously-included directories found matching 'pystan\stan\src\docs'
#       no previously-included directories found matching 'pystan\stan\src\doxygen'
#       no previously-included directories found matching 'pystan\stan\src\python'
#       no previously-included directories found matching 'pystan\stan\src\test'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\doc'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\doxygen'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\boost_*\doc'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\boost_*\libs'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\boost_*\more'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\boost_*\status'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\boost_*\tools'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\cpplint_*'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\eigen_*\unsupported\doc'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\lib\gtest_*'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\make'
#       no previously-included directories found matching 'pystan\stan\lib\stan_math\test'
#       warning: no previously-included files matching '*.html' found under directory 'pystan\stan\lib\stan_math'
#       warning: no previously-included files matching '*.css' found under directory 'pystan\stan\lib\stan_math'
#       adding license file 'LICENSE'
#       writing manifest file 'pystan.egg-info\SOURCES.txt'
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.src.stan.lang' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.src.stan.lang' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.src.stan.lang' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.src.stan.lang' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.src.stan.lang.grammars' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.src.stan.lang.grammars' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.src.stan.lang.grammars' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.src.stan.lang.grammars' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.lookuptable' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.lookuptable' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.lookuptable' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.lookuptable' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.hooks' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.hooks' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.hooks' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.hooks' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.lib' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.lib' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.lib' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.lib' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.licenses' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.licenses' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.licenses' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.licenses' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.arr.fun' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.arr.fun' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.arr.fun' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.arr.fun' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.core' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.core' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.core' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.core' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.mat.fun' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.mat.fun' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.mat.fun' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.mat.fun' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.mat.functor' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.mat.functor' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.mat.functor' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.mat.functor' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.mat.meta' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.mat.meta' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.mat.meta' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.mat.meta' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.mat.vectorize' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.mat.vectorize' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.mat.vectorize' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.mat.vectorize' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.scal.fun' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.scal.fun' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.scal.fun' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.scal.fun' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.fwd.scal.meta' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.fwd.scal.meta' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.fwd.scal.meta' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.fwd.scal.meta' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.memory' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.memory' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.memory' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.memory' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.mix' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.mix' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.mix' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.mix' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.mix.mat.fun' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.mix.mat.fun' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.mix.mat.fun' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.mix.mat.fun' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.mix.mat.functor' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.mix.mat.functor' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.mix.mat.functor' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.mix.mat.functor' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.opencl' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.opencl' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.opencl' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.opencl' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.opencl.err' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.opencl.err' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.opencl.err' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.opencl.err' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.opencl.kernels' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.opencl.kernels' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.opencl.kernels' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.opencl.kernels' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.prim' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.prim' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'pystan.stan.lib.stan_math.stan.math.prim' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'pystan.stan.lib.stan_math.stan.math.prim' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       c:\Users\Swati Rajwal\AppData\Local\Programs\Python\Python311\Lib\site-packages\setuptools\command\build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'pystan.stan.lib.stan_math.stan.math.prim.arr.err' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'pystan.stan.lib.stan_math.stan.math.prim.arr.err' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
# ...
#       creating build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl\adaptive_iterator_impl.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl\const_step_iterator_impl.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl\n_step_iterator_impl.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl\times_iterator_impl.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\impl
#       creating build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\integrate.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\integrate_adaptive.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\integrate_const.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\integrate_n_steps.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\integrate_times.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\null_observer.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\observer_collection.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate
#       creating build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail\functors.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail\integrate_adaptive.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail\integrate_const.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail\integrate_n_steps.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail\integrate_times.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\iterator\integrate\detail
#       creating build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\adams_bashforth.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\adams_bashforth_moulton.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\adams_moulton.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\bulirsch_stoer.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\bulirsch_stoer_dense_out.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\controlled_runge_kutta.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\controlled_step_result.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\dense_output_runge_kutta.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\euler.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\explicit_error_generic_rk.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\explicit_generic_rk.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\extrapolation_stepper.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\implicit_euler.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\modified_midpoint.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\rosenbrock4.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\rosenbrock4_controller.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\rosenbrock4_dense_output.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\runge_kutta4.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\runge_kutta4_classic.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\runge_kutta_cash_karp54.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\runge_kutta_cash_karp54_classic.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\runge_kutta_dopri5.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\runge_kutta_fehlberg78.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\stepper_categories.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\symplectic_euler.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\symplectic_rkn_sb3a_m4_mclachlan.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\symplectic_rkn_sb3a_mclachlan.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\velocity_verlet.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper
#       creating build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base\algebra_stepper_base.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base\explicit_error_stepper_base.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base\explicit_error_stepper_fsal_base.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base\explicit_stepper_base.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base\symplectic_rkn_stepper_base.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\base
#       creating build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\adams_bashforth_call_algebra.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\adams_bashforth_coefficients.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\adams_moulton_call_algebra.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\adams_moulton_coefficients.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\generic_rk_algorithm.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\generic_rk_call_algebra.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\generic_rk_operations.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail\rotating_buffer.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\detail
#       creating build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation\generation_controlled_runge_kutta.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation\generation_dense_output_runge_kutta.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation\generation_rosenbrock4.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation\generation_runge_kutta_cash_karp54.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation
#       copying pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation\generation_runge_kutta_cash_karp54_classic.hpp -> build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation
#       error: could not create 'build\lib.win-amd64-cpython-311\pystan\stan\lib\stan_math\lib\boost_1.69.0\boost\numeric\odeint\stepper\generation\generation_runge_kutta_cash_karp54_classic.hpp': No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pystan
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
def sim_bandit3arm_combined(param_dict, sd_dict, group_name, seed, num_sj=50, num_trial=200, model_name='bandit3arm_combined'):
    """simulate 3 arm bandit data for multiple subjects"""
    multi_subject = []

    # generate new params
    np.random.seed(seed)
    sample_params = dict()
    for key in param_dict:
        sample_params[key] = np.random.normal(param_dict[key], sd_dict[key], size=1)[0]

    for sj in range(num_sj):
        df_sj = model_bandit3arm_combined(sample_params, sj, group_name, num_trial)
        multi_subject.append(df_sj)

    df_out = pd.concat(multi_subject)
    # saving output
    output_dir = '/content/drive/MyDrive/Balloon Task (3 Arm Bandit)/sim_output_swati/bandit3arm_combined_sim_'+str(num_sj)+'/'
    # output_dir = './sim_output/bandit3arm_combined_sim_'+str(num_sj)+'/'
    if not os.path.isdir(output_dir):
        os.mkdir(output_dir)
    f_name = model_name+'_'+group_name+'_'+str(seed)+'_'+str(num_trial)+'_'+str(num_sj)
    df_out.to_csv(output_dir+f_name+'.txt', sep='\t', index=False)
    print(df_out)
    # return df_out

def model_bandit3arm_combined(param_dict, subjID, group_name, num_trial=200):
    """simulate 3-arm bandit choices and outcomes"""
    # load reward/pain probabilities
    pun_prob = pd.read_csv('/content/drive/MyDrive/Balloon Task (3 Arm Bandit)/probs/pain_prob3arm_t240_jakubSmooth_01_28_10_21_01358.csv').values
    rew_prob = pd.read_csv('/content/drive/MyDrive/Balloon Task (3 Arm Bandit)/probs/reward_prob3arm_t240_jakubSmooth_01_28_10_21_01358.csv').values

    # initialise values
    Qr = np.zeros(3)
    Qp = np.zeros(3)
    rt = 0

    # initial probabilities of choosing each deck
    pD = (1/3) * np.ones(3)

    # initialise output
    data_out = []
    # simulate trials
    for t in range(num_trial):
        # select a deck
        tmpDeck = int(np.random.choice(np.arange(3), size=1, p=pD, replace=True))

        # compute tmpRew and tmpPun
        tmpRew = int(np.random.binomial(size=1, n=1, p=rew_prob[t, tmpDeck]))
        tmpPun = -1 * int(np.random.binomial(size=1, n=1, p=pun_prob[t, tmpDeck])) # punishment=-1

        # compute PE and update values
        PEr = param_dict['R']*tmpRew - Qr[tmpDeck]
        PEp = param_dict['P']*tmpPun - Qp[tmpDeck]
        # PEr_fic = -Qr
        # PEp_fic = -Qp

        Qr_chosen, Qp_chosen = [], []
        Qr_chosen = Qr[tmpDeck]
        Qp_chosen = Qp[tmpDeck]

        # update Q with decay rate
        Qr = (1-param_dict['d']) * Qr
        Qp = (1-param_dict['d']) * Qp

        # update Qr and Qp
        # Qr += param_dict['Arew'] * PEr_fic
        # Qp += param_dict['Apun'] * PEp_fic

        # replace Q values of chosen deck with correct values
        Qr[tmpDeck] = Qr_chosen + (param_dict['Arew']+param_dict['Apun']) * PEr
        Qp[tmpDeck] = Qp_chosen + (param_dict['Arew']-param_dict['Apun']) * PEp

        # sum Q
        Qsum = Qr + Qp

        # update pD for next trial
        # pD_pre = np.exp(Qsum) / sum(np.exp(Qsum))
        pD_pre = softmax(Qsum-max(Qsum))

        # xi/lapse
        pD = pD_pre * (1.-param_dict['xi']) + param_dict['xi']/3.

        # output
        data_out.append([subjID, group_name, t, tmpDeck+1, rt, int(tmpRew), int(tmpPun)])

    df_out = pd.DataFrame(data_out)
    df_out.columns = ['subjID', 'group','trial', 'choice', 'rt', 'gain', 'loss']

    return df_out

def bandit_combined_preprocess_func(txt_path):
    """parse simulated data for pystan"""
    # Iterate through grouped_data
    subj_group = pd.read_csv(txt_path, sep='\t')

    # Use general_info(s) about raw_data
    subj_ls = np.unique(subj_group['subjID'])
    n_subj = len(subj_ls)
    t_subjs = np.array([subj_group[subj_group['subjID']==x].shape[0] for x in subj_ls])
    t_max = max(t_subjs)
    # print(t_subjs)

    # Initialize (model-specific) data arrays
    rew = np.full((n_subj, t_max), 0, dtype=float)
    los = np.full((n_subj, t_max), 0, dtype=float)
    choice = np.full((n_subj, t_max), -1, dtype=int)
    rt = np.full((n_subj, t_max), -1, dtype=float)
    subjID = np.full((n_subj),0,dtype=int)
    group_n = np.full(n_subj,'gr',dtype=object)

    # Write from subj_data to the data arrays
    for s in range(n_subj):
        subj_data = subj_group[subj_group['subjID']==subj_ls[s]]
        t = t_subjs[s]
        rew[s][:t] = subj_data['gain']
        los[s][:t] = -1 * np.abs(subj_data['loss'])  # Use abs
        choice[s][:t] = subj_data['choice']
        subjID[s] = pd.unique(subj_data['subjID'])
        rt[s][:t] = subj_data['rt']
        group_n[s] = pd.unique(subj_data['group'])[0]

    # Wrap into a dict for pystan
    data_dict = {
        'N': int(n_subj),
        'T': int(t_max),
        'Tsubj': t_subjs.astype(int),
        'rew': rew,
        'los': los,
        'choice': choice,
        'rt': rt,
        'subjID': subjID,
        'group': group_n
    }
    # print(data_dict)
    # Returned data_dict will directly be passed to pystan
    return data_dict

# %%
if __name__ == "__main__":
    # healthy control parameters (based on FAPIA, table 5.3 combined model params)
    param_dict_hc = {
        'Arew': 0.569,  # reward learning rate
        'Apun': 0.016,  # punishment learning rate
        'R':    9.417,  # reward sensitivity
        'P':    5.778,  # punishment sensitivity
        'xi':   0.026,  # lapse
        'd':    0.469   # decay
    }

    # assumed patient parameters
    param_dict_pt = {
        'Arew': 0.585,  # reward learning rate
        'Apun': 0.106,  # punishment learning rate
        'R':    12.750,  # reward sensitivity
        'P':    9.953,  # punishment sensitivity
        'xi':   0.105,   # lapse
        'd':    0.603   # decay
    }

    # control sd
    sd_dict_hc= {
        'Arew': 0.178,  # reward learning rate
        'Apun': 0.018,  # punishment learning rate
        'R':    5.031,  # reward sensitivity
        'P':    1.715,  # punishment sensitivity
        'xi':   0.003,   # lapse
        'd':    0.261   # decay
    }

    # patient sd
    sd_dict_pt = {
        'Arew': 0.300,  # reward learning rate
        'Apun': 0.010,  # punishment learning rate
        'R':    5.911,  # reward sensitivity
        'P':    1.577,  # punishment sensitivity
        'xi':   0.013,   # lapse
        'd':    0.311   # decay
    }

    # parsing cl arguments
    # group_name = sys.argv[1] # pt=patient, hc=control
    group_name = 'pt'
    # seed_num = int(sys.argv[2]) # seed number
    seed_num = 4
    # subj_num = int(sys.argv[3]) # subject number to simulate
    subj_num = 1
    # trial_num = int(sys.argv[4]) # trial number to simulate
    trial_num = 1

    model_name = 'bandit3arm_combined'
    if group_name == 'hc':
        # simulate hc subjects with given params
        sim_bandit3arm_combined(param_dict_hc, sd_dict_hc, group_name, seed=seed_num,num_sj=subj_num, num_trial=trial_num, model_name=model_name)
    elif group_name == 'pt':
        # simulate pt subjects with given params
        sim_bandit3arm_combined(param_dict_pt, sd_dict_pt, group_name, seed=seed_num, num_sj=subj_num, num_trial=trial_num, model_name=model_name)
    else:
        print('check group name (hc or pt)')

    # parse simulated data
    txt_path = f'/content/drive/MyDrive/Balloon Task (3 Arm Bandit)/sim_output_swati/bandit3arm_combined_sim_{subj_num}/bandit3arm_combined_{group_name}_{seed_num}_{trial_num}_{subj_num}.txt'
    # txt_path = f'./sim_output_swati/bandit3arm_combined_sim_{subj_num}/bandit3arm_combined_{group_name}_{seed_num}_{trial_num}_{subj_num}.txt'
    data_dict = bandit_combined_preprocess_func(txt_path)
    data_dict_gr = data_dict
    data_dict_gr.pop('group')
    # fit stan model
    model_code = open('/content/drive/MyDrive/Balloon Task (3 Arm Bandit)/models/bandit3arm_combLR_lapse_decay_b.stan','r').read()
    # model_code = open('./models/bandit3arm_combLR_lapse_decay_b.stan', 'r').read()
    posterior = stan.build(program_code=model_code, data=data_dict_gr)
    fit = posterior.sample(num_samples=2000, num_chains=4)
    df = fit.to_frame()  # pandas `DataFrame, requires pandas
    print(df['mu_Arew'].agg(['mean','var']))
    print(df['mu_Apun'].agg(['mean','var']))

    # saving traces
    pars = ['mu_Arew', 'mu_Apun', 'mu_R', 'mu_P', 'mu_xi','mu_d']
    df_extracted = df[pars]
    save_dir = '/content/drive/MyDrive/Balloon Task (3 Arm Bandit)/sim_output_swati/bandit3arm_combined_trace_'+str(subj_num)+'/'
    # save_dir = './sim_output/bandit3arm_combined_trace_'+str(subj_num)+'/'
    if not os.path.isdir(save_dir):
        os.mkdir(save_dir)
    sfile = save_dir + f'{group_name}_sim_{seed_num}_{trial_num}_{subj_num}.csv'
    df_extracted.to_csv(sfile, index=None)

    # # fit stan model (pystan2 version)
    # sm = pystan.StanModel(file='bandit3arm_combLR_lapse_decay_b.stan')
    # fit = sm.sampling(data=data_dict, iter=2000, chains=1)
    # print(fit)

    # # saving
    # pars = ['mu_Arew', 'mu_Apun', 'mu_R', 'mu_P', 'mu_xi','mu_d']
    # extracted = fit.extract(pars=pars, permuted=True)
    # # print(extracted)
    # sfile = f'./sim_output/bandit_combined_sim/{group_name}_sim_{seed_num}.pkl'
    # with open(sfile, 'wb') as op:
    #     tmp = { k: v for k, v in extracted.items() if k in pars } # dict comprehension
    #     pickle.dump(tmp, op)
# Out:
#    subjID group  trial  choice  rt  gain  loss
# 0       0    pt      0       3   0     0    -1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-cf8a05cb44f1> in <cell line: 1>()
#      69     model_code = open('/content/drive/MyDrive/Balloon Task (3 Arm Bandit)/models/bandit3arm_combLR_lapse_decay_b.stan','r').read()
#      70     # model_code = open('./models/bandit3arm_combLR_lapse_decay_b.stan', 'r').read()
# ---> 71     posterior = stan.build(program_code=model_code, data=data_dict_gr)
#      72     fit = posterior.sample(num_samples=2000, num_chains=4)
#      73     df = fit.to_frame()  # pandas `DataFrame, requires pandas
#
# /usr/local/lib/python3.9/dist-packages/stan/model.py in build(program_code, data, random_seed)
#     517
#     518     try:
# --> 519         return asyncio.run(go())
#     520     except KeyboardInterrupt:
#     521         return  # type: ignore
#
# /usr/lib/python3.9/asyncio/runners.py in run(main, debug)
#      31     """
#      32     if events._get_running_loop() is not None:
# ---> 33         raise RuntimeError(
#      34             "asyncio.run() cannot be called from a running event loop")
#      35
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
